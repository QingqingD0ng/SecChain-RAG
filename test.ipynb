# %%
import os
import json
from typing import Any
from unstructured.partition.pdf import partition_pdf
from unstructured.partition.docx import partition_docx
from unstructured.partition.doc import partition_doc
from unstructured.partition.xlsx import partition_xlsx
from unstructured.partition.image import partition_image
from pydantic import BaseModel
from logging_config import get_logger

# %%
class Element(BaseModel):
    type: str
    text: Any
    source: str

    def to_dict(self):
        return {
            "type": self.type,
            "text": self.text,
            "source": self.source 
        }

# %%
def convertToJson(array, filepath):
  elem_dict = []
  for elem in array:
    elem_dict.append(elem.to_dict())
  # Write the JSON output to a file
  with open(filepath, 'w') as json_file:
    json.dump(elem_dict, json_file, indent=4)

# %%
excelfilepath = 'Data/Guidelines/Ergebnis_des_IT-Grundschutz-Checks.xlsx'
elements = []
elements.extend([Element(type='xlsx', text=str(el), source='excel') for el in partition_xlsx(excelfilepath)])

# %%
# Out:
# [Element(type='xlsx', text='\n\n\nErfassungsdatum\nStandort\nName des Erfassers\nAnsprechpartner\nZielobjekt\nBaustein\nAnforderung\nAnforderungs-Typ\nUmsetzungsgrad\nUmsetzung bis\nUmsetzung\nRichtlinie\nDefizite/Kostenschätzung\nVerantwortlicher\n\n\n\n\n\n\nA001 Textverarbeitung, Präsentation, Tabellenkalkulation\nAPP.1.1 Office-Produkte\nAPP.1.1.A1 Sicherstellen der Integrität von Office-Produkten\nBasis\nJa\n\nEs werden nur offizielle Office-Produkte installiert. Die Updates werden aus sicheren Quellen bezogen. Falls vorhanden, werden digitale Signaturen oder Prüfsummen zur Sicherstellung der Integrität genutzt.\n\n\nIT-Betrieb\n\n\n\n\n\n\nA001 Textverarbeitung, Präsentation, Tabellenkalkulation\nAPP.1.1 Office-Produkte\nAPP.1.1.A2 Einschränken von Aktiven Inhalten\nBasis\nJa\n\nDas automatische Ausführen von aktiven Inhalten ist standardmäßig deaktiviert. Die Mitarbeiter werden regelmäßig auf die Gefahr von aktiven Inhalten hingewiesen.\n\n\nBenutzer\n\n\n\n\n\n\nA001 Textverarbeitung, Präsentation, Tabellenkalkulation\nAPP.1.1 Office-Produkte\nAPP.1.1.A3 öffnen von Dokumenten aus externen Quellen\nBasis\nJa\n\nDokumente, welche per Mail in das interne Netz gelangen werden vom Virenscanner auf Schadsoftware geprüft. Alte Dateiformate oder nicht mehr benötigte Dateiformate werden direkt abgefangen. Die Mitarbeiter werden auf die Gefahren aufmerksam gemacht.\n\n\nIT-Betrieb\n\n\n\n\n\n\nA001 Textverarbeitung, Präsentation, Tabellenkalkulation\nAPP.1.1 Office-Produkte\nAPP.1.1.A4 Absichern des laufenden Betriebs von Office-Produkten\nBasis\nJa\n\nDer IT-Betrieb und der ISB informieren sich regelmäßig über mögliche Schwachstellen. Updates werden durch die Updateverwaltung eingespielt. In der Security Policy werden die Vorgaben für die sichere Nutzung von Anwendungen definiert.\nSecurity Policy\n\nInformationssicherheitsbeauftragter\n\n\n\n\n\n\nA001 Textverarbeitung, Präsentation, Tabellenkalkulation\nAPP.1.1 Office-Produkte\nAPP.1.1.A5 Auswahl geeigneter Office-Produkte\nStandard\nJa\n\nDie Office-Produkte wurden anhand eines Anforderungskatalogs beschafft.\n\n\nIT-Betrieb\n\n\n\n\n\n\nA001 Textverarbeitung, Präsentation, Tabellenkalkulation\nAPP.1.1 Office-Produkte\nAPP.1.1.A6 Testen neuer Versionen von Office-Produkten\nStandard\nJa\n\nNeue Versionen werden zuerst nur für bestimmte Mitarbeiter installiert. Diese testen die Funktionalität im Hinblick auf die Dokumentenvorlagen, Formulare etc.\n\n\nBenutzer\n\n\n\n\n\n\nA001 Textverarbeitung, Präsentation, Tabellenkalkulation\nAPP.1.1 Office-Produkte\nAPP.1.1.A7 Installation und Konfiguration von Office-Produkten\nStandard\nJa\n\nDie Konfiguration der Office-Produkte sind im Systemmanagement dokumentiert.\n\n\nIT-Betrieb\n\n\n\n\n\n\nA001 Textverarbeitung, Präsentation, Tabellenkalkulation\nAPP.1.1 Office-Produkte\nAPP.1.1.A8 Versionskontrolle von Office-Produkten\nStandard\nJa\n\nDie Updateverwaltung führt regelmäßig einen Abgleich der aktuellen Version mit der installierten Version durch. Zusätzlich lässt sich im Systemmanagement nachvollziehen, auf welchem Client die Software installiert ist. Die Konfigurationen sind im Systemmanagement dokumentiert.\n\n\nIT-Betrieb\n\n\n\n\n\n\nA001 Textverarbeitung, Präsentation, Tabellenkalkulation\nAPP.1.1 Office-Produkte\nAPP.1.1.A9 Beseitigung von Restinformationen vor Weitergabe von Dokumenten\nStandard\nJa\n\nDie Dokumente der RECPLAST GmbH sind klassifiziert. Je nach Klassifizierung sind Tätigkeiten an Dokumenten durchzuführen, bevor diese weitergegeben werden. Dokumente sind immer in pdf-Dateiformat zu versenden.\nRichtlinie zur Lenkung von Dokumenten und Aufzeichnungen\n\nBenutzer\n\n\n\n\n\n\nA001 Textverarbeitung, Präsentation, Tabellenkalkulation\nAPP.1.1 Office-Produkte\nAPP.1.1.A10 Regelung der Software-Entwicklung durch Endbenutzer\nStandard\nJa\n\nEigenentwicklungen durch die Mitarbeiter sind nicht erlaubt.\n\n\nBenutzer\n\n\n\n\n\n\nA001 Textverarbeitung, Präsentation, Tabellenkalkulation\nAPP.1.1 Office-Produkte\nAPP ...

# %%
convertToJson(elements, 'output.json')

# %%
pdffilepath = 'Data/Guidelines/Beschreibung_Recplast.pdf'
pdf_elements = []
pdf_elements.extend([Element(type='pdf', text=str(el), source='pdf') for el in partition_pdf(pdffilepath, languages=["eng", "deu"], strategy="hi_res", hi_res_model_name="yolox", pdf_infer_table_structure=True)])

# %%
pdf_elements
# Out:
# [Element(type='pdf', text='FR Bundesamt u für Sicherheit in der Informationstechnik', source='pdf'),
#  Element(type='pdf', text='Beschreibung des Beispielunternehmens RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='Bundesamt für Sicherheit in der Informationstechnik Postfach 20 03 63 53133 Bonn Tel.: +49 22899 9582-5369 E-Mail: grundschutz@bsi.bund.de Internet: https://www.bsi.bund.de © Bundesamt für Sicherheit in der Informationstechnik 2020', source='pdf'),
#  Element(type='pdf', text='Inhaltsverzeichnis', source='pdf'),
#  Element(type='pdf', text='Verzeichnis der Abbildungen ........................................................................................................................................................ 3 Tabellenverzeichnis ........................................................................................................................................................................... 4 Einleitung zu diesem Dokument...................................................................................................................................... 5 Beschreibung der RECPLAST GmbH .............................................................................................................................. 6 Geltungsbereich ....................................................................................................................................................................... 7 3.1. Organisatorische Gliederung .................................................................................................................................. 7 3.2. Standorte und Mitarbeiter........................................................................................................................................ 7 3.3. Vereinfachter Netzplan der RECPLAST.............................................................................................................. 8 3.4. Informationstechnik................................................................................................................................................... 9 Sicherheitsmanagement .................................................................................................................................................... 11 4.1. Initiierung des Sicherheitsprozesses ..................................................................................................................11 4.2. Entwicklung der Leitlinie zur Informationssicherheit ..............................................................................11 4.3. Inhalt der Leitlinie zur Informationssicherheit ............................................................................................12 Strukturanalyse ...................................................................................................................................................................... 14 5.1. Erfassung der Geschäftsprozesse, Anwendungen und Informationen ..............................................14 5.2. Erhebung des Netzplans ..........................................................................................................................................25 5.3. Erhebung der IT-Systeme .......................................................................................................................................27 5.4. Erhebung der räumlichen Gegebenheiten ......................................................................................................36 5.5. Liste der Dienstleister ...............................................................................................................................................37 Schutzbedarfsfeststellung ................................................................................................................................................. 39 6.1. Anpassung der Schutzbedarfskategorien ........................................................................................................39 6.2. Schutzbedarfsfeststellung für Geschäftsprozesse ........................................................................................40 6.3. Schutzbedarfsfeststellung für Anwendungen ...............................................................................................42 6.4. Schutzbedarfsfeststellung für IT-Systeme ......................................................................................................44 6.5. Schutzbedarfsfeststellung für Kommunikationsverbindungen ............. ...
#  Element(type='pdf', text='1.', source='pdf'),
#  Element(type='pdf', text='2.', source='pdf'),
#  Element(type='pdf', text='3.', source='pdf'),
#  Element(type='pdf', text='4.', source='pdf'),
#  Element(type='pdf', text='5.', source='pdf'),
#  Element(type='pdf', text='6.', source='pdf'),
#  Element(type='pdf', text='8.', source='pdf'),
#  Element(type='pdf', text='9.', source='pdf'),
#  Element(type='pdf', text='9.6.', source='pdf'),
#  Element(type='pdf', text='Risikoanalyse auf Geschäftsprozessebene .......................................................................................................64', source='pdf'),
#  Element(type='pdf', text='9.7.', source='pdf'),
#  Element(type='pdf', text='Risikobehandlung ......................................................................................................................................................66', source='pdf'),
#  Element(type='pdf', text='10. Realisierungsplan .................................................................................................................................................................. 69', source='pdf'),
#  Element(type='pdf', text='Seite 2 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='Verzeichnis der Abbildungen', source='pdf'),
#  Element(type='pdf', text='Abbildung 1: Organigramm der RECPLAST GmbH ............................................................................................................ 7 Abbildung 2: Vereinfachter Netzplan der RECPLAST ........................................................................................................ 8 Im Netz des Standorts Bad Godesberg (siehe Abbildung 3) werden die folgenden Server für folgende Zwecke eingesetzt: ............................................................................................................................................................................. 9 Abbildung 3: Detaillierter Netzplan der RECPLAST GmbH .......................................................................................... 26 Abbildung 4: Risikomatrix ........................................................................................................................................................... 63', source='pdf'),
#  Element(type='pdf', text='Seite 3 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='Tabellenverzeichnis', source='pdf'),
#  Element(type='pdf', text='Tabelle 1: Zuordnung Geschäftsprozesse zu den Standorten ....................................................................................... 15 Tabelle 2: Ausschnitt mit den wichtigsten Geschäftsprozessen ................................................................................... 18 Tabelle 3: Anwendungen der RECPLAST GmbH ................................................................................................................ 23 Tabelle 4: Beispiel für die Zuordnung von Geschäftsprozessen zu Anwendungen ............................................. 25 Tabelle 5: Übersicht über die IT-Systeme............................................................................................................................... 31 Tabelle 6: Übersicht über die Industrial Control System (ICS) ..................................................................................... 31 Tabelle 7: Übersicht über die Internet of Things-Systeme (IoT) ................................................................................... 32 Tabelle 8: Beispiel für die Zuordnung von Anwendungen zu Servern ...................................................................... 32 Tabelle 9: Beispiel für die Zuordnung Clients zu Anwendungen ................................................................................ 34 Tabelle 10: exemplarische Übersicht über die Netz- und Telekommunikationskomponenten .................... 35 Tabelle 11: Übersicht über Kommunikationsverbindungen ......................................................................................... 36 Tabelle 12: Beispiel für Gebäude und Räume ....................................................................................................................... 37 Tabelle 13: Zuordnung Räume zu IT-Systemen .................................................................................................................. 37 Tabelle 14: Liste der Dienstleister .............................................................................................................................................. 38 Tabelle 15: Schutzbedarf Geschäftsprozesse ........................................................................................................................ 42 Tabelle 16: Schutzbedarf Anwendungen ............................................................................................................................... 44 Tabelle 17: Schutzbedarf IT-Systeme ...................................................................................................................................... 47 Tabelle 18: Schutzbedarf Kommunikationsverbindungen ........................................................................................... 49 Tabelle 19: Schutzbedarf Räume ............................................................................................................................................... 50 Tabelle 20: Modellierung .............................................................................................................................................................. 53 Tabelle 21: Grundschutz-Check ISMS.1 ................................................................................................................................. 56 Tabelle 22: Grundschutz-Check APP.1.1 ................................................................................................................................ 58 Tabelle 23: Grundschutz-Check SYS.2.2.3 ............................................................................................................................. 59 Tabelle 24: Gefährdungsübersicht ............................................................................................................................................ 61 Tabelle 25: Definition Eintrittshäufigkeiten ........................................................................................................................ 6 ...
#  Element(type='pdf', text='Seite 4 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='1. Einleitung zu diesem Dokument', source='pdf'),
#  Element(type='pdf', text='In diesem Dokument werden die einzelnen Schritte bei der Variante „Standard-Absicherung“ der IT- Grundschutz-Methodik nach BSI Standard 200-2 veranschaulicht. Das Dokument richtet sich an alle, die an der Umsetzung des IT-Grundschutzes interessiert sind oder diesen bereits umgesetzt haben. Die Anwender des IT-Grundschutzes sollen durch dieses Dokument eine ausführliche Hilfestellung und wertvolle praktische Umsetzungstipps erhalten. Der Aufbau des Dokuments orientiert sich an der Vorgehensweise der IT-Grundschutz-Methodik. Zuerst wird das fiktive Beispielunternehmen RECPLAST GmbH beschrieben und anschließend die einzelnen Schritte des IT-Grundschutzes an der RECPLAST GmbH durchgespielt.', source='pdf'),
#  Element(type='pdf', text='Der Darstellung liegt die Edition 2019 des IT-Grundschutz-Kompendiums zugrunde.', source='pdf'),
#  Element(type='pdf', text='Aus Gründen der Lesbarkeit wurde in den Dokumenten die männliche Form gewählt, dennoch beziehen sich die Angaben auf Angehörige aller Geschlechter.', source='pdf'),
#  Element(type='pdf', text='Seite 5 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='2. Beschreibung der RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='Die RECPLAST GmbH produziert und vertreibt etwa 400 unterschiedliche, aus Recyclingmaterialien gefertigte Kunststoffprodukte, zum Beispiel Bauelemente wie Rund- und Brettprofile, Zäune, Blumenkübel oder Abfallbehälter, teils in größeren Serien für Endkunden, teils spezifisch für einzelne Geschäftskunden.', source='pdf'),
#  Element(type='pdf', text='Das Auftragsvolumen, die Häufigkeit der Aufträge und die Kunden variieren: Es gibt einige wenige Stamm- und Großkunden und zahlreiche Einzelkunden.', source='pdf'),
#  Element(type='pdf', text='Der jährliche Gesamtumsatz des Unternehmens beläuft sich auf ca. 50 Millionen Euro bei einem Gewinn von etwa einer Million Euro.', source='pdf'),
#  Element(type='pdf', text='Seite 6 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='3. Geltungsbereich', source='pdf'),
#  Element(type='pdf', text='Der Informationsverbund der RECPLAST ist wie folgt definiert:', source='pdf'),
#  Element(type='pdf', text='• Kurzbezeichnung: RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='Langbezeichnung: Die RECPLAST GmbH mit allen Geschäftsprozessen, Anwendungen und IT- Systemen zur Erbringung der Produktion.', source='pdf'),
#  Element(type='pdf', text='Der Informationsverbund erstreckt sich auf die gesamte RECPLAST GmbH.', source='pdf'),
#  Element(type='pdf', text='3.1. Organisatorische Gliederung', source='pdf'),
#  Element(type='pdf', text='Die organisatorische Gliederung der RECPLAST GmbH gibt das in Abbildung 1 dargestellte Organigramm wieder:', source='pdf'),
#  Element(type='pdf', text="Geschäftsführung i ICS-Informations- | Sicherheits- [ beauftragter nn eS aa -----l--- a Datenschutz- | ' \\nformationssicherheits- | | beauftragter | 1 beauftragter | mm | I I ] Verwaltung Einkauf Produktion Merbeting werd Lager und Logistik Personal |_| Entwicklung Vertriebsbüros Buchhaltung Fertigung Informations- | technik Haus- und Gebäudetechnik Legende —— Organisationseinheit —— Stabstelle", source='pdf'),
#  Element(type='pdf', text='Abbildung 1: Organigramm der RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='3.2. Standorte und Mitarbeiter', source='pdf'),
#  Element(type='pdf', text='Die Geschäftsführung hat zusammen mit den Verwaltungsabteilungen und den Abteilungen für Einkauf, Marketing und Vertrieb ein neues Gebäude in Bad Godesberg bezogen, während Entwicklung, Produktion, Material- und Auslieferungslager am ursprünglichen Firmensitz im Bonner Stadtteil Beuel verblieben sind.', source='pdf'),
#  Element(type='pdf', text='Zusätzlich gibt es Vertriebsbüros in Berlin, München und Paderborn.', source='pdf'),
#  Element(type='pdf', text='Seite 7 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='Darüber hinaus nutzen Mitarbeiter ihre Laptops und verbinden sich remote mit dem Firmennetzwerk.', source='pdf'),
#  Element(type='pdf', text='Das Unternehmen beschäftigt insgesamt rund 500 Mitarbeiter, von denen 175 in der Verwaltung in Bad Godesberg, 310 in der Produktion und im Lager in Beuel und jeweils drei Mitarbeiter in den Vertriebsbüros in Berlin, München und Paderborn tätig sind.', source='pdf'),
#  Element(type='pdf', text='3.3. Vereinfachter Netzplan der RECPLAST', source='pdf'),
#  Element(type='pdf', text='In der untenstehenden Darstellung wird der Aufbau des Netzes der RECPLAST vereinfacht veranschaulicht.', source='pdf'),
#  Element(type='pdf', text='Bonn Bad-Godesberg Sa H Clients IT Clients Geschäfts- Clients führung Marketing’Vertrieb Server Clients Cients Personal Einkauf Tk-Aniage DMZ © Internet Switch ! Router Router Firewall ReCoBS Router 1 a 1 == ı 2 I 3 Vertriebsstandorte l © Berlin, München, I = Paderborn ı 8 a ! Switch ReCoBS Router Clients B Entwicklung TK-Anlage Clients Fertigung/Lager e Produkfons- maschinen Sewer', source='pdf'),
#  Element(type='pdf', text='Abbildung 2: Vereinfachter Netzplan der RECPLAST', source='pdf'),
#  Element(type='pdf', text='Seite 8 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='3.4. Informationstechnik', source='pdf'),
#  Element(type='pdf', text='Am Standort Bad Godesberg ist im Zuge des Umzugs ein zentral administriertes Windows-Netz mit insgesamt 126 angeschlossenen Arbeitsplätzen eingerichtet worden. Die Arbeitsplatzclients sind einheitlich mit dem Betriebssystem Windows 10, den üblichen Büro-Anwendungen (Standardsoftware für Textverarbeitung, Tabellenkalkulation und für die Erstellung von Präsentationen) und Client- Software zur E-Mail-Nutzung ausgestattet. Zusätzlich ist je nach Aufgabengebiet auf verschiedenen Clients Spezialsoftware installiert.', source='pdf'),
#  Element(type='pdf', text='Den Mitarbeitern des Standorts Bad Godesberg stehen zusätzlich 42 Laptops zur Verfügung.', source='pdf'),
#  Element(type='pdf', text='Im Netz des Standorts Bad Godesberg (siehe Abbildung 3) werden die folgenden Server für folgende Zwecke eingesetzt:', source='pdf'),
#  Element(type='pdf', text='• Zwei Server dienen als Virtualisierungshosts,', source='pdf'),
#  Element(type='pdf', text='• Ein virtueller Server dient als Domänen-Controller (Virtualisierungshost 1),', source='pdf'),
#  Element(type='pdf', text='ein virtueller Server dient der Dateiablage (Virtualisierungshost 1),', source='pdf'),
#  Element(type='pdf', text='ein virtueller Server dient als Druckserver (Virtualisierungshost 1),', source='pdf'),
#  Element(type='pdf', text='ein virtueller Server dient als Wiki-Server (Virtualisierungshost 2),', source='pdf'),
#  Element(type='pdf', text='ein virtueller Server dient als internes Ticketsystem (Virtualisierungshost 2),', source='pdf'),
#  Element(type='pdf', text='• ein Server dient als Backupserver,', source='pdf'),
#  Element(type='pdf', text='ein virtueller Server dient als Windows-Update-Server (Virtualisierungshost 2),', source='pdf'),
#  Element(type='pdf', text='ein virtueller Sever dient als Linux-Update-Server (Virtualisierungshost 2),', source='pdf'),
#  Element(type='pdf', text='', source='pdf'),
#  Element(type='pdf', text='• ein Server dient als Cloudserver,', source='pdf'),
#  Element(type='pdf', text='ein Server dient als Datenbankserver für die Personal- und Finanzdaten,', source='pdf'),
#  Element(type='pdf', text='', source='pdf'),
#  Element(type='pdf', text='ein weiterer Datenbankserver dient der Kunden- und Auftragsbearbeitung,', source='pdf'),
#  Element(type='pdf', text='ein weiterer Datenbankserver dient dem Systemmanagement,', source='pdf'),
#  Element(type='pdf', text='ein Server dient als Kommunikations-Server (Mail-Server, Termin- und Adressverwaltung).', source='pdf'),
#  Element(type='pdf', text='Die beiden Virtualisierungshosts sind unabhängig voneinander konfiguriert und betreiben unterschiedliche virtuelle Maschinen. Alle IT-Systeme auf den Virtualisierungsservern werden als einzelne virtuelle Maschinen betrieben.', source='pdf'),
#  Element(type='pdf', text='Der Standort Beuel verfügt über weitere IT-Systeme. Die Produktion erfolgt durch zwei leistungsfähige, speicherprogrammierbare Maschinen, die über den Server zur Produktionssteuerung kontrolliert und konfiguriert werden. Darüber hinaus werden die Produktionsprozesse durch ein SCADA-System (Supervisory Control and Data Acquisition-System) überwacht. Die Programme und Konfigurationen werden in der Entwicklungsabteilung erstellt. Die Arbeitsplatzclients in Beuel haben die gleiche Grundausstattung wie die Clients in der Verwaltung in Bad Godesberg. Zusätzlich ist auf mehreren PCs CAD/CAM-Software (CAD/CAM: Computer Aided Design/Computer Aided Manufacturing) installiert.', source='pdf'),
#  Element(type='pdf', text='Am Standort Beul gibt es weitere Server:', source='pdf'),
#  Element(type='pdf', text='• Virtualisierungsserver', source='pdf'),
#  Element(type='pdf', text='ο Virtueller Server 1.1 Domänen-Controller', source='pdf'),
#  Element(type='pdf', text='ο Virtueller Server 1.2 Dateiserver', source='pdf'),
#  Element(type='pdf', text='ο Virtueller Server 1.3 Druckserver', source='pdf'),
#  Element(type='pdf', text='• Server für die Produktionssteuerung', source='pdf'),
#  Element(type='pdf', text='Seite 9 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='• Server für die Betriebsdatenerfassung.', source='pdf'),
#  Element(type='pdf', text='Den Mitarbeitern des Standorts Beuel stehen 80 Arbeitsplatzclients und 19 Laptops zur Verfügung.', source='pdf'),
#  Element(type='pdf', text='Die beiden Standorte Bad Godesberg und Beuel sind über eine angemietete Standleitung miteinander verbunden.', source='pdf'),
#  Element(type='pdf', text='Die Vertriebsbüros sind jeweils mit einem PC ausgestattet (Betriebssystem ist ebenfalls Windows 10) und über DSL an das Internet angebunden. Der Zugriff auf das Unternehmensnetz erfolgt mittels Authentisierung und VPN. Den Mitarbeitern der Vertriebsbüros stehen je 3 Laptops zur Verfügung', source='pdf'),
#  Element(type='pdf', text='Von unterwegs aus erfolgt der Remote-Zugriff auf das Unternehmensnetz über VPN.', source='pdf'),
#  Element(type='pdf', text='Das Unternehmensnetz ist über DSL an das Internet angebunden. Der Internet-Zugang ist über eine Firewall und einen Switch mit Paketfilter abgesichert. Alle Clients haben E-Mail-Zugang sowie die Möglichkeit zur freien Internetrecherche. Die Webseite des Unternehmens wird auf einem Webserver des Providers vorgehalten.', source='pdf'),
#  Element(type='pdf', text='Weitere, zu berücksichtigende Informationstechnik:', source='pdf'),
#  Element(type='pdf', text='• Telekommunikationsanlagen in Bad Godesberg und Beuel,', source='pdf'),
#  Element(type='pdf', text='• Alarmanlagen zur Sicherung der Gebäude in Bad Godesberg und Beuel,', source='pdf'),
#  Element(type='pdf', text='acht Faxgeräte (davon vier in Bad Godesberg, jeweils eins in den Vertriebsbüros und eins in Beuel).', source='pdf'),
#  Element(type='pdf', text='Für den reibungslosen Betrieb der Informationstechnik an allen Standorten ist die zentrale IT-Abteilung in Bad Godesberg verantwortlich.', source='pdf'),
#  Element(type='pdf', text='Eine Anweisung regelt den Umgang mit der betrieblichen Informationstechnik, diese darf ausschließlich für Firmenzwecke genutzt werden und das Einbringen von privater Hard- und Software ist untersagt.', source='pdf'),
#  Element(type='pdf', text='Seite 10 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='4. Sicherheitsmanagement', source='pdf'),
#  Element(type='pdf', text='In diesem Abschnitt werden am Beispiel der RECPLAST GmbH einige Grundelemente eines Managementsystems für Informationssicherheit dargestellt. Der Schwerpunkt liegt auf der Initiierung des Sicherheitsprozesses und dabei insbesondere auf das Sicherheitsmanagement und der Entwicklung einer Leitlinie zur Informationssicherheit.', source='pdf'),
#  Element(type='pdf', text='Umfassende Informationen zu den behandelten Themen und weiteren Aspekten, die beim Aufbau eines Managementsystems für Informationssicherheit zu berücksichtigen sind, finden Sie in folgenden Dokumenten:', source='pdf'),
#  Element(type='pdf', text='BSI-Standard 200-1: Managementsysteme für Informationssicherheit (ISMS),', source='pdf'),
#  Element(type='pdf', text='BSI-Standard 200-2: IT-Grundschutz-Methodik, insbesondere Kapitel 3 und 4, sowie', source='pdf'),
#  Element(type='pdf', text='', source='pdf'),
#  Element(type='pdf', text='IT-Grundschutz-Kompendium', source='pdf'),
#  Element(type='pdf', text='4.1. Initiierung des Sicherheitsprozesses', source='pdf'),
#  Element(type='pdf', text='Die Geschäftsführung der RECPLAST GmbH beabsichtigt, ein Sicherheitskonzept ausarbeiten zu lassen, das in allen Unternehmensbereichen umgesetzt werden soll. Dazu müssen die vorhandenen Grundsätze und Richtlinien zur Informationssicherheit überprüft und angepasst werden.', source='pdf'),
#  Element(type='pdf', text='In einem ersten Schritt wird ein Informationssicherheitsbeauftragter (ISB) ernannt, der die zugehörigen Arbeiten koordinieren soll. Da diese Aufgabe umfangreiche IT-Kenntnisse erfordert, wird hierfür ein Mitarbeiter der Abteilung „Informationstechnik“ bestimmt, in seinen Aufgaben aber gleichzeitig ICS- Informationssicherheitsbeauftragten (ICS-ISB), der Sicherheitsanforderungen und -maßnahmen für den Produktionsbereich entwickeln und kontrollieren soll.', source='pdf'),
#  Element(type='pdf', text='Zur initialen Erstellung des Sicherheitskonzeptes wird ein „Sicherheitskonzept“ eingerichtet, das folgende Ergebnisse erzielen soll: zeitlich befristetes Projekt', source='pdf'),
#  Element(type='pdf', text='1. Erstellung von Vorschlägen und Entscheidungsvorlagen für eine Leitlinie zur Informationssicherheit.', source='pdf'),
#  Element(type='pdf', text='2. Erstellung eines Vorschlags für ein Sicherheitskonzept und einen zugehörigen Realisierungsplan.', source='pdf'),
#  Element(type='pdf', text='3. Erstellung eines Vorschlags für Maßnahmen zur Aufrechterhaltung der Informationssicherheit.', source='pdf'),
#  Element(type='pdf', text='4. Dokumentation aller Entscheidungsvorlagen, Entscheidungen und der umgesetzten Maßnahmen des Informationssicherheitsprozesses.', source='pdf'),
#  Element(type='pdf', text='Da der ISB die Geschäftsprozesse nicht im Detail kennt, wird ein IS-Management-Team gebildet, das den ISB und den ICS-ISB bei der Erstellung der Leitlinie und dem Sicherheitskonzept unterstützt. Dem IS-Management-Team gehören der Datenschutzbeauftragte, die Leiter des kaufmännischen Bereichs und der Rechtsabteilung und, um Kundenanforderungen einzubeziehen, ein Mitarbeiter des Vertriebs an. So sind alle Geschäftsbereiche vertreten und können weitere Informationen über die Betriebsabläufe und externe Anforderungen einholen.', source='pdf'),
#  Element(type='pdf', text='Das Projekt wird dem Betriebsrat vorgestellt, der regelmäßig über Zwischenergebnisse informiert wird. Auch die Mitarbeiter werden in einer Betriebsversammlung mit dem Projekt und seinen Zielen bekannt gemacht.', source='pdf'),
#  Element(type='pdf', text='4.2. Entwicklung der Leitlinie zur Informationssicherheit', source='pdf'),
#  Element(type='pdf', text='Die zuständige Projektgruppe erarbeitet idealerweise in zwei halbtägigen Sitzungen einen ersten Entwurf für eine Leitlinie. Dieser wird mit der Geschäftsführung abgestimmt und in einer weiteren Sitzung den Abteilungsleitungen und dem Betriebsrat vorgestellt. Die Diskussion zu dem anzustrebenden Sicherheitsniveau, sowie den vorgesehenen organisatorischen Regelungen, führt in der', source='pdf'),
#  Element(type='pdf', text='Seite 11 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='Regel nur zu geringfügigen Änderungen, denen alle Beteiligten zustimmen. Die verabschiedete Leitlinie wird von der Geschäftsführung unterschrieben und auf einer Betriebsversammlung vorgestellt. Sie verdeutlicht den Stellenwert der Informationssicherheit für das Unternehmen und erläutert die Ziele und daraus abgeleiteten Maßnahmen der Leitlinie. Die in der Leitlinie formulierten Regelungen sind ab dem Zeitpunkt ihres Inkrafttretens verbindlich.', source='pdf'),
#  Element(type='pdf', text='Die Kommunikation der Leitlinie erfolgt über das interne Wiki-System. Die Geschäftsführung kündigt zudem an, die Belegschaft künftig verstärkt für Informationssicherheit zu sensibilisieren. In Schulungen soll das Wissen über mögliche Gefährdungen und zweckmäßige Gegenmaßnahmen gefördert und der sichere Umgang mit Informationen und Informationstechnik eingeübt werden.', source='pdf'),
#  Element(type='pdf', text='4.3. Inhalt der Leitlinie zur Informationssicherheit', source='pdf'),
#  Element(type='pdf', text='Stellenwert der Informationssicherheit und Bedeutung dieser Leitlinie', source='pdf'),
#  Element(type='pdf', text='Der Erfolg der RECPLAST GmbH hängt in besonderem Maße davon ab, dass die Geschäftsinformationen aktuell und unverfälscht sind und bei Bedarf mit der gebotenen Vertraulichkeit behandelt werden.', source='pdf'),
#  Element(type='pdf', text='Informationstechnik ist in allen Geschäftsbereichen eine wichtige Ressource. Sie wird auch immer wichtiger in den Beziehungen zu Kunden, Zulieferern, Partnerunternehmen, der öffentlichen Verwaltung und anderen Informationstechnik und ein sicherheitsbewusster Umgang mit ihr sind daher ein wesentlicher Eckpfeiler des Unternehmenserfolges.', source='pdf'),
#  Element(type='pdf', text='Mit der Leitlinie erkennt die Geschäftsführung ausdrücklich an, dass die Gewährleistung der Verfügbarkeit, Integrität und Vertraulichkeit der geschäftskritischen Informationen eine kontinuierlich, zu verfolgende Aufgabe ist und geeignete organisatorische Grundlagen erfordert.', source='pdf'),
#  Element(type='pdf', text='Die Leitlinie wird durch ein alle Unternehmensbereiche umfassendes Sicherheitskonzept ergänzt. Bei der Entwicklung dieses Konzepts stützt sich die RECPLAST GmbH auf die IT-Grundschutz-Methodik und die Vorgaben in der Informationstechnik. Regelmäßige Überprüfungen sollen dafür sorgen, dass Leitlinie und das Sicherheitskonzept angemessen und aktuell bleiben.', source='pdf'),
#  Element(type='pdf', text='Sicherheitsniveau und Ziele', source='pdf'),
#  Element(type='pdf', text='Insbesondere für auftragsbezogene Entscheidungen und Investitionen sind aktuelle und korrekte Informationen unabdingbar. Ausfälle der Informationstechnik, die zu spürbaren Beeinträchtigungen bei der Abwicklung von Aufträgen, in der internen Kommunikation oder in den Beziehungen mit Kunden und Geschäftspartnern führen, sind nicht vertretbar.', source='pdf'),
#  Element(type='pdf', text='Die Geschäftsführung der RECPLAST GmbH hat entschieden, dass ein angemessenes Sicherheitsniveau für einen normalen Schutzbedarf angestrebt werden soll. Grundlage für diese Entscheidung war eine Gefährdungsabschätzung über die Werte der zu schützenden Güter sowie des vertretbaren Aufwands an Personal und Finanzmitteln für Informationssicherheit. Dies bedeutet im Einzelnen:', source='pdf'),
#  Element(type='pdf', text='1. Um Informationssicherheit gewährleisten zu können, sind angemessene technische und organisatorische Maßnahmen erforderlich. Diese können nur dann hinreichend wirksam sein, wenn alle Beschäftigten die möglichen Gefährdungen für die Informationssicherheit kennen und in ihren Aufgabenbereichen entsprechend verantwortlich handeln. Regelmäßige Fortbildungen zur Informationssicherheit können hierbei unterstützen.', source='pdf'),
#  Element(type='pdf', text='2. Vertraulichkeit und Integrität der für das Unternehmen wichtigen Informationen sind zu schützen, unabhängig davon, in welcher Form sie vorliegen. Auch im Umgang mit elektronischen Dokumenten und Informationen ist daher Geheimhaltungsanweisungen strikt Folge zu leisten.', source='pdf'),
#  Element(type='pdf', text='3. Die Informationstechnik muss so betrieben werden, dass Geschäftsinformationen hinreichend schnell verfügbar sind. Ausfälle, die zu Terminüberschreitungen von mehr als einem Tag bei der Abwicklung von Aufträgen oder anderen wichtigen Geschäftsvorhaben führen, sind nicht tolerierbar.', source='pdf'),
#  Element(type='pdf', text='Seite 12 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='4. Die Maßnahmen für Informationssicherheit sollen auch dazu beitragen, dass die für das Unternehmen relevanten Gesetze, Vorschriften und vertragliche Verpflichtungen eingehalten werden.', source='pdf'),
#  Element(type='pdf', text='5. Finanzielle Schäden und ein negatives Image für das Unternehmen müssen verhindert werden.', source='pdf'),
#  Element(type='pdf', text='Verantwortlichkeiten', source='pdf'),
#  Element(type='pdf', text='Die Geschäftsführung trägt die Gesamtverantwortung für die Informationssicherheit im Unternehmen, den Sicherheitsprozess und die zugehörigen Maßnahmen.', source='pdf'),
#  Element(type='pdf', text='Für die Koordination und Überwachung aller auf Informationssicherheit bezogenen Aktivitäten wird von der Geschäftsführung die Stabsstelle eines Informationssicherheitsbeauftragten geschaffen. Der zuständige Mitarbeiter ist gleichzeitig zentraler Ansprechpartner für alle Fragen rund um das Thema Informationssicherheit und der Geschäftsführung berichtspflichtig.', source='pdf'),
#  Element(type='pdf', text='Informationstechnik wird auch im Kernprozess der Firma, der Fertigung, immer wichtiger. Für die spezifischen Fragestellungen zur Sicherheit der Produktionssysteme und deren Steuerung wird daher mit dem ICS-Sicherheitsbeauftragten eine eigene Stelle geschaffen, die eng mit dem Informa- tionssicherheitsbeauftragten zusammenarbeitet.', source='pdf'),
#  Element(type='pdf', text='Informationssicherheitsbeauftragter und ICS-Sicherheitsbeauftragter bilden gemeinsam mit weiteren von der Geschäftsführung benannten Mitarbeitern ein IS-Management-Team, das für die Aufrechterhaltung technischen Sicherheitsmaßnahmen im Unternehmen zuständig ist.', source='pdf'),
#  Element(type='pdf', text='Für alle Informationen, Geschäftsprozesse sowie die unterstützenden informationstechnischen Systeme und und Systemeigentümer, Eigentümer von Zielobjekten) benannt. Diese sind dafür zuständig, die geschäftliche Bedeutung von Informationen und Technik einzuschätzen und darauf zu achten, dass die Mitarbeiter dieser Bedeutung entsprechend handeln. Sie verwalten Zugriffsrechte und Autorisierungen in ihrem Zuständigkeitsbereich und sind gegenüber der Leitung rechenschaftspflichtig. Sie sind auch dafür verantwortlich, externen Dienstleistern und Kooperationspartnern die Vorgaben der RECPLAST GmbH zur Informationssicherheit zur Kenntnis zu geben und deren Einhaltung zu überwachen.', source='pdf'),
#  Element(type='pdf', text='Jeder Mitarbeiter soll dazu beitragen, Sicherheitsvorfälle und Verletzungen der Integrität, Vertraulichkeit und Verfügbarkeit von Informationen zu vermeiden. Erkannte Fehler sind den Zuständigen umgehend zu melden, damit schnellstmöglich Abhilfemaßnahmen eingeleitet werden können.', source='pdf'),
#  Element(type='pdf', text='Geltung und Folgen von Zuwiderhandlungen', source='pdf'),
#  Element(type='pdf', text='Diese Leitlinie zur Informationssicherheit gilt für die gesamte RECPLAST GmbH. Jede Mitarbeiterin und jeder Mitarbeiter ist daher angehalten, sicherheitsbewusst mit betrieblich wichtigen Informationen und der Informationstechnik umzugehen und verbindliche Sicherheitsregeln zu befolgen.', source='pdf'),
#  Element(type='pdf', text='Beabsichtigte oder grob fahrlässige Handlungen, die Sicherheitsvorgaben verletzen, können finanzielle Verluste bedeuten, Mitarbeiter, Geschäftspartner und Kunden schädigen oder den Ruf des Unternehmens gefährden. Bewusste Verstöße gegen verpflichtende Sicherheitsregeln können arbeitsrechtliche und unter Umständen auch strafrechtliche Konsequenzen haben und zu Regressforderungen führen.', source='pdf'),
#  Element(type='pdf', text='Seite 13 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='5. Strukturanalyse', source='pdf'),
#  Element(type='pdf', text='Grundlage eines im betrachteten Informationsverbund vorhandenen Informationen, ihres Stellenwertes für Geschäftsprozesse und Anwendungen sowie der organisatorischen und technischen Rahmenbedingungen, in denen sie verwendet und verarbeitet werden. Bei der Strukturanalyse geht es darum, die dazu erforderlichen Informationen zusammenzustellen und so aufzubereiten, dass sie die weiteren Schritte der IT- Grundschutz-Methodik unterstützen. Ein sinnvoller Ausgangspunkt für die Strukturanalyse sind die Geschäftsprozesse einer Institution. Es ist danach zu fragen, welche Anwendungen und Informationen jeweils wichtig für einzelne Geschäftsprozesse sind. Anschließend können die technischen Systeme und Infrastrukturkomponenten ermittelt und den Anwendungen zugeordnet werden. Zur Strukturanalyse gehören folglich die folgenden Teilschritte:', source='pdf'),
#  Element(type='pdf', text='1. Erfassung der zum Informationsverbundes gehörigen Geschäftsprozesse, Anwendungen und Informationen,', source='pdf'),
#  Element(type='pdf', text='2. Netzplanerhebung,', source='pdf'),
#  Element(type='pdf', text='3. Erfassung der IT-Systeme sowie', source='pdf'),
#  Element(type='pdf', text='4. Erfassung der Räume und Gebäude.', source='pdf'),
#  Element(type='pdf', text='Bei allen Schritten können der Umfang und die Komplexität der erhobenen Informationen durch die Bildung angemessener Gruppen reduziert werden.', source='pdf'),
#  Element(type='pdf', text='Weitere Informationen zur Strukturanalyse finden Sie in Kapitel 8.1 des BSI-Standards 200-2.', source='pdf'),
#  Element(type='pdf', text='5.1. Erfassung der Geschäftsprozesse, Anwendungen und Informationen', source='pdf'),
#  Element(type='pdf', text='Das Organigramm (siehe Abbildung 1) veranschaulicht die organisatorische Gliederung der RECPLAST GmbH.', source='pdf'),
#  Element(type='pdf', text='Jeder Abteilung lassen sich verschiedene Geschäftsprozesse zuordnen, beispielsweise', source='pdf'),
#  Element(type='pdf', text='• Einkauf: Der Prozess Einkauf,', source='pdf'),
#  Element(type='pdf', text='Informationstechnik: Prozesse wie der Betrieb von Servern und Clients, Benutzer-Service, Verwaltung des Mobile Device Management, oder Netzadministration,', source='pdf'),
#  Element(type='pdf', text='• Marketing & Vertrieb: Pflege der Webseite,', source='pdf'),
#  Element(type='pdf', text='• Personalabteilung: Prozesse wie Einstellung, Entlassung und Gehaltszahlung sowie', source='pdf'),
#  Element(type='pdf', text='Fertigung der Produktionsabteilung: Die Prozesse zur Umwandlung der Altkunststoffe in wiederverwertbare Regranulate sowie zur Herstellung der neuen Produkte aus diesen Rohmaterialien.', source='pdf'),
#  Element(type='pdf', text='Viele dieser Prozesse können weiter untergliedert werden, beispielsweise die Server-Administration in die Teilprozesse Verwaltung von Mail-, Datei- und Datenbankservern, zu denen jeweils Aktivitäten wie Patch-Management, Datensicherung, Konfiguration oder Dokumentation gehören.', source='pdf'),
#  Element(type='pdf', text='Die Zuordnung der Prozesse zu den Standorten der RECPLAST GmbH erfolgt tabellarisch.', source='pdf'),
#  Element(type='pdf', text='Geschäftsprozess Standort Bad- Godesberg Standort Beuel Standort Vertriebsbüros GP001 Produktion X GP002 Angebotswesen X GP003 Auftragsabwicklung X', source='pdf'),
#  Element(type='pdf', text='Seite 14 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='Standort Bad- Godesberg', source='pdf'),
#  Element(type='pdf', text='Standort Beuel', source='pdf'),
#  Element(type='pdf', text='Standort Vertriebsbüros', source='pdf'),
#  Element(type='pdf', text='Geschäftsprozess GP004 Einkauf X GP005 Disposition X GP006 Personalverwaltung X GP006a Gehaltszahlung X GP006b Neueinstellung X GP006c Entlassung Mitarbeiter X GP007 IT-Betrieb X X X GP007a Betrieb Server X X GP007b Betrieb Clients X X X GP007c Betrieb Netze X X GP007d Betrieb Produktions-IT X X GP008 Betrieb der Webseite X X GP009 Betrieb des Intranets X GP010 Verwaltung des Mobile Device Managements X GP011 Nutzung einer Cloud-Umgebung X X X', source='pdf'),
#  Element(type='pdf', text='Tabelle 1: Zuordnung Geschäftsprozesse zu den Standorten', source='pdf'),
#  Element(type='pdf', text='Die folgende Tabelle enthält einen Ausschnitt mit den wichtigsten Geschäftsprozessen (GP). Hinter dem Kürzel „GP“ folgt eine Prozessnummer. In der kurzen Beschreibung wird erläutert, welche Informationen verarbeitet werden und um was für einen GP es sich handelt. In der Spalte Prozess-Art wird angegeben, ob es sich um einen Kern- oder unterstützenden Prozess handelt. Die für einen Prozess benötigten Anwendungen werden in Tabelle 3 zugeordnet.', source='pdf'),
#  Element(type='pdf', text='Kürzel Name Beschreibung Prozess-Art GP001 Produktion Die Produktion der Kunststoffartikel umfasst alle Phasen von der Materialbereitstellung bis zur Einlagerung des produzierten Materials. Hierzu gehören innerhalb der Produktion die internen Transportwege, die Produktion und Fertigung der verschiedenen Komponenten und das Verpacken der Teile. Es werden alle Informationen über Aufträge, Lagerbestände und Stücklisten verarbeitet. Kerngeschäft Mitarbeiter: Produktion', source='pdf'),
#  Element(type='pdf', text='Seite 15 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='Kürzel Name Beschreibung GP002 Angebotswesen In der Angebotsabwicklung werden die Kundenanfragen für Produkte verarbeitet. Im Regelfall werden Kundenanfragen formlos per E-Mail oder Fax geschickt. Die Angebote werden elektronisch erfasst und ein schriftliches Angebot per Post oder Mail an den Kunden versendet. Im Angebotswesen werden Kundendaten, Lagerbestände, Anfragen und Angebote bearbeitet. Mitarbeiter: Vertrieb GP003 Auftragsabwicklung Kunden schicken die Bestellungen im Regelfall per Fax oder E-Mail. Zusätzlich bietet die Webseite der RECPLAST einen Webshop an, über den Bestellungen aufgegeben werden können. Bestellungen erzeugen eine automatisch generierte Mail. Alle Belege müssen ausgedruckt und elektronisch erfasst werden. Eine Auftragsbestätigung erhält der Kunde nur, wenn er dies ausdrücklich wünscht oder der Produktionsprozess von der üblichen Produktionszeit abweicht. Die Auftragsabwicklung verwendet Kundendaten, Lagerbestände, Aufträge und Bestellungen. Mitarbeiter: Vertrieb GP004 Einkauf Prozess-Art Unterstützender Prozess Kerngeschäft Unterstützender Prozess', source='pdf'),
#  Element(type='pdf', text='In der Einkaufsabteilung werden alle erforderlichen Artikel bestellt, die nicht für den Produktionsprozess erforderlich sind. In dieser Abteilung werden externe Projekte verhandelt, IT-Verträge gestaltet und Verbrauchsmaterial im organisatorischen Umfeld (Papier, Toner etc.) beschafft. Die verwendeten Informationen sind Lagerbestände, Bedarfsmeldungen und Informationen über Lieferanten.', source='pdf'),
#  Element(type='pdf', text='Mitarbeiter:', source='pdf'),
#  Element(type='pdf', text='Einkauf', source='pdf'),
#  Element(type='pdf', text='GP005', source='pdf'),
#  Element(type='pdf', text='Disposition', source='pdf'),
#  Element(type='pdf', text='In der Disposition werden alle für die Produktion benötigten Materialien (Kunststoffe, Schrauben, Tüten, etc.) beschafft. Hierzu liegen normalerweise Rahmenverträge vor. Geplant wird in diesem Umfeld anhand von Jahresplanmengen und verschiedenen Bestellwerten.', source='pdf'),
#  Element(type='pdf', text='Kerngeschäft', source='pdf'),
#  Element(type='pdf', text='Seite 16 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='Kürzel Name Mitarbeiter: GP006 Personalverwaltung Mitarbeiter: GP006a Gehaltszahlung Mitarbeiter: GP006b Neueinstellung Mitarbeiter: GP007 IT-Betrieb Mitarbeiter: GP007a Betrieb Server Mitarbeiter: GP007b Betrieb Clients Beschreibung Disposition, Produktion In dieser Abteilung werden alle Aufgaben bearbeitet, die zur administrativen Abwicklung des Personalwesens erforderlich sind. Die dazu genutzten Daten sind personenbezogen. Geschäftsführung, Personal Teilprozess von GP006. In der Personalabteilung wird insbesondere die monatliche Gehaltszahlung vorbereitet und durchgeführt. Die dazu genutzten Daten sind personenbezogen. Personal Teilprozess von GP006. Die Abteilung ist auch an der Neueinstellung von Mitarbeitern beteiligt. Es fallen Informationen an, die dem Datenschutz unterliegen. Geschäftsführung, Personal Die IT-Abteilung sorgt für den störungsfreien Betrieb der IT- Infrastruktur der Server, Clients und Netze. Beim Betrieb der Produktions-IT wird sie von Mitarbeitern der Produktionsabteilung unterstützt. Es wird mit Konfigurationsdaten der IT- Systeme gearbeitet. Informationstechnik Teilprozess von GP007. Dieser Prozess umfasst Beschaffung, Installation, Konfiguration und Pflege der erforderlichen Hard- und Software. Dazu wird mit Konfigurationsdaten der Systeme gearbeitet. Informationstechnik Prozess-Art Unterstützender Prozess Unterstützender Prozess Unterstützender Prozess Unterstützender Prozess Unterstützender Prozess Unterstützender Prozess', source='pdf'),
#  Element(type='pdf', text='Teilprozess von GP007. Dieser Prozess umfasst Beschaffung, Installation, Konfiguration und Pflege der erforderlichen Hard- und Software sowie die Beratung der Nutzer. Dazu wird mit Konfigurationsdaten der Systeme gearbeitet.', source='pdf'),
#  Element(type='pdf', text='Mitarbeiter:', source='pdf'),
#  Element(type='pdf', text='IT-Betrieb', source='pdf'),
#  Element(type='pdf', text='Seite 17 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='Kürzel Name Beschreibung Prozess-Art GP007c Betrieb Netze Teilprozess von GP007. Der Prozess umfasst Beschaffung, Installation, Konfiguration und Pflege der aktiven Komponenten sowie – gemeinsam mit der Abteilung Haustechnik – Verlegung und Wartung der Übertragungsleitungen. Dazu wird mit Konfigurationsdaten der Netzkomponenten gearbeitet. Unterstützender Prozess Mitarbeiter: IT-Betrieb GP007d Betrieb Produktions-IT Teilprozess von GP007. In diesem Prozess werden Beschaffung, Installation und Betrieb der IT-Systeme durchgeführt, die für Überwachung und Steuerung der Produktion erforderlich sind. Verantwortlich ist der Leiter der Produktionsabteilung unter Mitwirkung der IT-Abteilung. Es wird mit Konfigurationsdaten der Systeme und Produktionsdaten gearbeitet. Unterstützender Prozess Mitarbeiter: IT-Betrieb GP008 Betrieb der Webseite Die Webseite wird durch einen externen Dienstleister gehostet. Unterstützender Prozess Die Webseite enthält Neuigkeiten, Ansprechpartner, Kontaktformular und einen Shop. Mitarbeiter: Vertrieb GP009 Betrieb des Intranets Das Intranet ist eine Wiki-Web- Unterstützender Prozess Anwendung. Hierüber werden Dokumente und neue interne Informationen verteilt. Mitarbeiter: Alle Mitarbeiter GP010 Verwaltung des Mobile Device Managements Die RECPLAST GmbH nutzt zur Verwaltung der Smartphones und Tablets ein Mobile Device Management. Unterstützender Prozess', source='pdf'),
#  Element(type='pdf', text='Mitarbeiter:', source='pdf'),
#  Element(type='pdf', text='Informationstechnik', source='pdf'),
#  Element(type='pdf', text='GP011', source='pdf'),
#  Element(type='pdf', text='Nutzung einer Cloud-Umgebung', source='pdf'),
#  Element(type='pdf', text='Die Cloud dient zum Datenaustausch zwischen mobilem Endgerät und den Clients bzw. Notebooks.', source='pdf'),
#  Element(type='pdf', text='Unterstützender Prozess', source='pdf'),
#  Element(type='pdf', text='Mitarbeiter:', source='pdf'),
# ...
#  Element(type='pdf', text='Seite 63 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='Gefährdung Eintrittshäufigkeit Auswirkungen G 0.23 Unbefugtes Eindringen in IT-Systeme mittel existenzbedrohend G 0.25 Ausfall von Geräten oder Systemen selten begrenzt G 0.26 Fehlfunktion von Geräten oder Systemen selten begrenzt G 0.27 Ressourcenmangel selten begrenzt G 0.28 Software- Schwachstellen oder -Fehler mittel beträchtlich G 0.29 Verstoß gegen Gesetze oder Regelungen selten begrenzt G 0.30 Unberechtigte Nutzung oder Administration von Geräten und Systemen mittel beträchtlich G 0.31 Fehlerhafte Nutzung oder Administration von Geräten und Systemen selten begrenzt G 0.32 Missbrauch von Berechtigungen mittel begrenzt G 0.39 Schadprogramme häufig begrenzt G 0.40 Verhinderung von Diensten (Denial of Service) selten begrenzt G 0.43 Einspielen von Nachrichten mittel beträchtlich G 0.44 Unbefugtes Eindringen in Räumlichkeiten selten begrenzt G 0.45 Datenverlust selten begrenzt G 0.46 Integritätsverlust schützenswerter Informationen mittel begrenzt Risiko hoch gering gering gering mittel gering mittel gering gering mittel gering mittel gering gering mittel', source='pdf'),
#  Element(type='pdf', text='Tabelle 28: Risikobewertung', source='pdf'),
#  Element(type='pdf', text='9.6. Risikoanalyse auf Geschäftsprozessebene', source='pdf'),
#  Element(type='pdf', text='Gefährdung Eintrittshäufigkeit Auswirkungen G 0.1 Feuer selten beträchtlich G 0.2 Ungünstige klimatische Bedingungen selten begrenzt G 0.3 Wasser selten beträchtlich G 0.4 Verschmutzung, Staub, Korrosion mittel beträchtlich G 0.5 Naturkatastrophen selten existenzbedrohend G 0.6 Katastrophen im Umfeld selten existenzbedrohend Risiko mittel gering gering mittel hoch hoch', source='pdf'),
#  Element(type='pdf', text='Seite 64 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='Gefährdung G 0.7 Großereignisse im Umfeld G 0.8 Ausfall oder Störung der Stromversorgung G 0.9 Ausfall oder Störung von Kommunikationsnetzen G 0.10 Ausfall oder Störung von Versorgungsnetzen G 0.11 Ausfall oder Störung von Dienstleistern G 0.12 Elektromagnetische Störstrahlung G 0.13 Abfangen kompromittierender Strahlung G 0.14 Ausspähen von Informationen (Spionage) G 0.15 Abhören G 0.16 Diebstahl von Geräten, Datenträgern oder Dokumenten G 0.17 Verlust von Geräten, Datenträgern oder Dokumenten G 0.18 Fehlplanung oder fehlende Anpassung G 0.19 Offenlegung schützenswerter Informationen G 0.20 Informationen oder Produkte aus unzuverlässiger Quelle G 0.21 Manipulation von Hard- oder Software G 0.22 Manipulation von Informationen G 0.23 Unbefugtes Eindringen in IT-Systeme Eintrittshäufigkeit Auswirkungen selten begrenzt mittel existenzbedrohend mittel existenzbedrohend mittel existenzbedrohend selten begrenzt selten vernachlässigbar selten vernachlässigbar selten begrenzt selten begrenzt selten begrenzt selten begrenzt mittel beträchtlich mittel beträchtlich mittel begrenzt mittel existenzbedrohend selten beträchtlich selten beträchtlich Risiko gering hoch hoch hoch gering gering gering gering gering gering gering mittel mittel gering hoch mittel mittel', source='pdf'),
#  Element(type='pdf', text='G 0.24 Zerstörung von Geräten oder Datenträgern', source='pdf'),
#  Element(type='pdf', text='mittel', source='pdf'),
#  Element(type='pdf', text='mittel', source='pdf'),
#  Element(type='pdf', text='existenzbedrohend', source='pdf'),
#  Element(type='pdf', text='hoch', source='pdf'),
#  Element(type='pdf', text='G 0.25 Ausfall von Geräten oder Systemen', source='pdf'),
#  Element(type='pdf', text='mittel', source='pdf'),
#  Element(type='pdf', text='mittel', source='pdf'),
#  Element(type='pdf', text='existenzbedrohend', source='pdf'),
#  Element(type='pdf', text='hoch', source='pdf'),
#  Element(type='pdf', text='G 0.26 Fehlfunktion von Geräten oder Systemen', source='pdf'),
#  Element(type='pdf', text='G 0.27 Ressourcenmangel', source='pdf'),
#  Element(type='pdf', text='mittel mittel', source='pdf'),
#  Element(type='pdf', text='mittel', source='pdf'),
#  Element(type='pdf', text='mittel', source='pdf'),
#  Element(type='pdf', text='existenzbedrohend', source='pdf'),
#  Element(type='pdf', text='beträchtlich', source='pdf'),
#  Element(type='pdf', text='beträchtlich', source='pdf'),
#  Element(type='pdf', text='hoch', source='pdf'),
#  Element(type='pdf', text='mittel', source='pdf'),
#  Element(type='pdf', text='G 0.28 Software- Schwachstellen oder -Fehler', source='pdf'),
#  Element(type='pdf', text='selten', source='pdf'),
#  Element(type='pdf', text='beträchtlich', source='pdf'),
#  Element(type='pdf', text='beträchtlich', source='pdf'),
#  Element(type='pdf', text='mittel', source='pdf'),
#  Element(type='pdf', text='Seite 65 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='Gefährdung Eintrittshäufigkeit Auswirkungen Risiko G 0.29 Verstoß gegen Gesetze oder Regelungen selten begrenzt gering G 0.30 Unberechtigte Nutzung oder Administration von Geräten und Systemen mittel beträchtlich mittel G 0.31 Fehlerhafte Nutzung oder Administration von Geräten und Systemen mittel beträchtlich mittel G 0.32 Missbrauch von Berechtigungen mittel beträchtlich mittel G 0.33 Personalausfall mittel beträchtlich mittel G 0.35 Nötigung, Erpressung oder Korruption selten begrenzt gering G 0.36 Identitätsdiebstahl mittel beträchtlich mittel G 0.37 Abstreiten von Handlungen selten begrenzt gering G 0.38 Missbrauch personenbezogener Daten selten begrenzt gering G 0.39 Schadprogramme mittel beträchtlich mittel G 0.40 Verhinderung von Diensten (Denial of Service) selten begrenzt gering G 0.41 Sabotage mittel existenzbedrohend hoch G 0.42 Social Engineering mittel beträchtlich mittel G 0.43 Einspielen von Nachrichten selten begrenzt gering G 0.44 Unbefugtes Eindringen in Räumlichkeiten selten begrenzt gering G 0.45 Datenverlust selten begrenzt gering G 0.46 Integritätsverlust schützenswerter Informationen mittel beträchtlich mittel', source='pdf'),
#  Element(type='pdf', text='Tabelle 29: Risikoanalyse Geschäftsprozess', source='pdf'),
#  Element(type='pdf', text='9.7. Risikobehandlung', source='pdf'),
#  Element(type='pdf', text='Im Anschluss an die Risikobewertung ist zu entscheiden, wie die identifizierten Risiken zu behandeln sind. Dabei kommen gemäß BSI-Standard 200-3 grundsätzlich vier Möglichkeiten der Risikobehandlung infrage, und zwar', source='pdf'),
#  Element(type='pdf', text='• die Risikovermeidung beispielsweise durch Verzicht auf risikobehaftete Prozesse oder technische Komponenten,', source='pdf'),
#  Element(type='pdf', text='• die Risikoreduktion beispielsweise durch zusätzliche Maßnahmen zur Verringerung von Schadensauswirkungen, Eintrittshäufigkeiten oder beidem,', source='pdf'),
#  Element(type='pdf', text='• der Risikotransfer beispielsweise durch Abschluss einer Versicherung zur Vorbeugung gegen finanzielle Schäden,', source='pdf'),
#  Element(type='pdf', text='Seite 66 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='• die Risikoakzeptanz beispielsweise, weil die mit dem Risiko verbundenen Chancen genutzt werden sollen und zusätzliche Maßnahmen zur Reduktion oder Verlagerung des Risikos für nicht erforderlich angesehen werden.', source='pdf'),
#  Element(type='pdf', text='Im nachfolgenden wird die Risikobehandlung für das Zielobjekt S007 Virtualisierungsserver dargestellt:', source='pdf'),
#  Element(type='pdf', text='Gefährdung Risikobehandlungsoption G 0.8 Ausfall oder Störung der Stromversorgung Risikoreduktion: Es soll eine redundante Stromversorgung geschaffen werden. G 0.9 Ausfall oder Störung von Kommunikationsnetzen Risikoreduktion: Es soll ein zweiter Internetprovider beauftragt werden. G 0.14 Ausspähen von Informationen (Spionage) Risikoreduktion: Es soll eine Zwei-Faktor-Authentifizierung eingerichtet werden. G 0.15 Abhören Risikoreduktion: Es soll eine Zwei-Faktor-Authentifizierung eingerichtet werden. G 0.16 Diebstahl von Geräten, Datenträgern oder Dokumenten Risikoakzeptanz: Aufgrund der bereits umgesetzten Maßnahmen wird das Restrisiko als vertretbar eingeschätzt. G 0.18 Fehlplanung oder fehlende Anpassung Risikoakzeptanz: Aufgrund der bereits umgesetzten Maßnahmen wird das Restrisiko als vertretbar eingeschätzt. G 0.19 Offenlegung schützenswerter Informationen Risikoreduktion: Es soll eine Angriffserkennung sowie eine Zwei-Faktor- Authentifizierung eingerichtet werden. G 0.20 Informationen oder Produkte aus unzuverlässiger Quelle Risikoakzeptanz: Aufgrund der bereits umgesetzten Maßnahmen wird das Restrisiko als vertretbar eingeschätzt. G 0.21 Manipulation von Hard- oder Software Risikoreduktion: Es soll eine Angriffserkennung eingerichtet werden. G 0.22 Manipulation von Informationen Risikoreduktion: Es soll eine Angriffserkennung eingerichtet werden. G 0.23 Unbefugtes Eindringen in IT- Systeme Risikoreduktion: Es soll eine Angriffserkennung sowie eine Zwei-Faktor- Authentifizierung eingerichtet werden. G 0.25 Ausfall von Geräten oder Systemen Risikoakzeptanz: Aufgrund der bereits umgesetzten Maßnahmen wird das Restrisiko als vertretbar eingeschätzt. G 0.26 Fehlfunktion von Geräten oder Systemen Risikoakzeptanz: Aufgrund der bereits umgesetzten Maßnahmen wird das Restrisiko als vertretbar eingeschätzt.', source='pdf'),
#  Element(type='pdf', text='G 0.27 Ressourcenmangel', source='pdf'),
#  Element(type='pdf', text='Risikoakzeptanz:', source='pdf'),
#  Element(type='pdf', text='Aufgrund der bereits umgesetzten Maßnahmen wird das Restrisiko als vertretbar eingeschätzt.', source='pdf'),
#  Element(type='pdf', text='Seite 67 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='Gefährdung G 0.28 Software-Schwachstellen oder -Fehler G 0.29 Verstoß gegen Gesetze oder Regelungen G 0.30 Unberechtigte Nutzung oder Administration von Geräten und Systemen G 0.31 Fehlerhafte Nutzung oder Administration von Geräten und Systemen G 0.32 Missbrauch von Berechtigungen G 0.39 Schadprogramme G 0.40 Verhinderung von Diensten (Denial of Service) G 0.43 Einspielen von Nachrichten G 0.44 Unbefugtes Eindringen in Räumlichkeiten G 0.45 Datenverlust G 0.46 Integritätsverlust schützenswerter Informationen Risikobehandlungsoption Risikoreduktion: Es soll eine Angriffserkennung eingerichtet werden. Risikoakzeptanz: Aufgrund der bereits umgesetzten Maßnahmen wird das Restrisiko als vertretbar eingeschätzt. Risikoreduktion: Es sollen geteilte Kennwörter zur Administration von kritischen Vorgängen eingerichtet werden. Risikoakzeptanz: Aufgrund der bereits umgesetzten Maßnahmen wird das Restrisiko als vertretbar eingeschätzt. Risikoakzeptanz: Aufgrund der bereits umgesetzten Maßnahmen wird das Restrisiko als vertretbar eingeschätzt. Risikoreduktion: Es soll Appliaction Whitelisting eingesetzt sowie eine Angriffserkennung eingerichtet werden. Risikoakzeptanz: Aufgrund der bereits umgesetzten Maßnahmen wird das Restrisiko als vertretbar eingeschätzt. Risikoreduktion: Es soll eine Angriffserkennung eingerichtet werden. Risikoakzeptanz: Aufgrund der bereits umgesetzten Maßnahmen wird das Restrisiko als vertretbar eingeschätzt. Risikoakzeptanz: Aufgrund der bereits umgesetzten Maßnahmen wird das Restrisiko als vertretbar eingeschätzt. Risikoreduktion:', source='pdf'),
#  Element(type='pdf', text='Es sollen geteilte Kennwörter zur Administration von kritischen Vorgängen eingerichtet werden.', source='pdf'),
#  Element(type='pdf', text='Tabelle 30: Risikobehandlung', source='pdf'),
#  Element(type='pdf', text='Seite 68 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='RECPLAST GmbH', source='pdf'),
#  Element(type='pdf', text='10. Realisierungsplan', source='pdf'),
#  Element(type='pdf', text='Als Ergebnis aus IT-Grundschutz-Check und der Entscheidungen zur Risikoplan ergibt sich eine Liste an Maßnahmen, die umgesetzt werden sollen, um die relevanten und dem Schutzbedarf des Informationsverbundes entsprechenden Sicherheitsanforderungen zu erfüllen. Bei der Umsetzungs- oder Realisierungsplanung geht es nun darum,', source='pdf'),
#  Element(type='pdf', text='• das Zusammenwirken der einzelnen Maßnahmen zu prüfen, bei Bedarf einzelne Maßnahmen zu konkretisieren oder unnötige Redundanzen durch Ausschluss von Maßnahmen zu verhindern, um so zu einer angemessenen, konsolidierten Maßnahmenliste zu gelangen,', source='pdf'),
#  Element(type='pdf', text='• die einmaligen und regelmäßigen Aufwände der verbliebenen Maßnahmen zu schätzen,', source='pdf'),
#  Element(type='pdf', text='für deren Umsetzung Termine und Verantwortliche festzulegen sowie', source='pdf'),
#  Element(type='pdf', text='• Entscheidungen zu begleitenden Maßnahmen zu treffen, die eine erfolgreiche Umsetzung zu erleichtern können.', source='pdf'),
#  Element(type='pdf', text='Das folgende Beispiel zeigt Maßnahmen für ausgewählte Zielobjekte. Auf Anmerkungen der zugehörigen Entscheidungen zu Terminen, Budget und Verantwortlichkeiten wurde in diesem Beispiel verzichtet.', source='pdf'),
#  Element(type='pdf', text='Zielobjekt Anforderung Umzusetzende Maßnahme C001 – C009 Clients SYS.2.1.A12 Kompatibilitätsprüfung von Software Der Beschaffungsprozess wird von der Einkaufsabteilung überarbeitet und vervollständigt. SYS.2.1.A17 Einsatzfreigabe Es wird ein Freigabeprozess definiert und eingesetzt. SYS.2.1.A21 Verhinderung der unautorisierten Nutzung von Rechnermikrofonen und Kameras Aufgrund der Vielzahl an Videokonferenzen der Mitarbeiter des Vertriebs wird die Funktion für alle Mitarbeiter des Vertriebs aktiviert. SYS.2.1.A37 Schutz vor unbefugten Anmeldungen Es wird eine Zwei-Faktor- Authentisierung angeschafft. SYS.2.2.3.A4 Telemetrie und Datenschutzeinstellungen Nach erfolgreicher Prüfung wird über das Deaktivieren der Einstellungen entschieden. GB001 Verwaltungsgebäude Bad Godesberg, GB002 Produktionsgebäude Beuel INF.4.A5 Abnahme der IT-Verkabelung Es wird bezüglich der Nutzung des Protokolls sensibilisiert. INF.4.A7 Entfernen und Deaktivieren nicht mehr benötigter IT-Verkabelung Die IT-Verkabelungen werden auf nicht mehr benötigte Kabel überprüft. N002 Firewall NET.3.2.A16 Aufbau einer „P-A-P“- Struktur Es wird eine P-A-P-Netzstruktur aufgebaut. NET.3.2.A26 Auslagerung von funktionalen Erweiterungen auf dedizierte Hardware Beim Erreichen des End of Life-Cycles wird eine neue dedizierte Firewall angeschafft.', source='pdf'),
#  Element(type='pdf', text='NET.3.2.A29 Einsatz von Hochverfügbarkeitslösungen', source='pdf'),
#  Element(type='pdf', text='Es soll eine weitere Firewall beschafft werden.', source='pdf'),
#  Element(type='pdf', text='Tabelle 31: Umsetzungsplanung', source='pdf'),
#  Element(type='pdf', text='Seite 69 von 69', source='pdf'),
#  Element(type='pdf', text='Version 1.0', source='pdf')]

# %%
convertToJson(pdf_elements, 'pdfoutput.json')
